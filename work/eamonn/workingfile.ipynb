# %%
# import modules
import pandas as pd

# %%
# Scrape data and check for number of records per year
years = (2015, 2016, 2017, 2018, 2019)

all_COLI_data = []

for year in years:
    url = 'https://www.numbeo.com/cost-of-living/rankings_by_country.jsp?title=' + str(year)
    print(url)
    COLI_data = pd.read_html(url)
    print(len(COLI_data[2]))
    all_COLI_data.append(COLI_data[2])

# %%
df_2015 = pd.DataFrame(all_COLI_data[0])
df_2016 = pd.DataFrame(all_COLI_data[1])
df_2017 = pd.DataFrame(all_COLI_data[2])
df_2018 = pd.DataFrame(all_COLI_data[3])
df_2019 = pd.DataFrame(all_COLI_data[4])
ranking_df = pd.concat([df_2015, df_2016, df_2017,df_2018,df_2019 ])
#ranking_df.to_csv("/Users/eamonnmccallum/Monash-DS/groupwork/STDs/work/data/numbeo_ranking_raw.csv")
ranking_df

# %%
continent  = pd.read_csv("/Users/eamonnmccallum/Monash-DS/groupwork/STDs/work/data/country-and-continent-codes-list-csv_csv.csv")
continent["country_names"] = continent["Country_Name"].astype(str) + ","
check = continent.loc[continent["Continent_Name"]== "North America"]
check
# Out:
#     Continent_Name Continent_Code                          Country_Name  \
# 7    North America            NaN                   Antigua and Barbuda
# 13   North America            NaN          Bahamas, Commonwealth of the
# 18   North America            NaN                              Barbados
# 20   North America            NaN                               Bermuda
# 27   North America            NaN                                Belize
# 30   North America            NaN                British Virgin Islands
# 38   North America            NaN                                Canada
# 40   North America            NaN                        Cayman Islands
# 55   North America            NaN               Costa Rica, Republic of
# 57   North America            NaN                     Cuba, Republic of
# 63   North America            NaN             Dominica, Commonwealth of
# 64   North America            NaN                    Dominican Republic
# 66   North America            NaN              El Salvador, Republic of
# 92   North America            NaN                             Greenland
# 93   North America            NaN                               Grenada
# 94   North America            NaN                            Guadeloupe
# 96   North America            NaN                Guatemala, Republic of
# 99   North America            NaN                    Haiti, Republic of
# 102  North America            NaN                 Honduras, Republic of
# 114  North America            NaN                               Jamaica
# 140  North America            NaN                            Martinique
# 143  North America            NaN         Mexico, United Mexican States
# 148  North America            NaN                            Montserrat
# 156  North America            NaN                  Netherlands Antilles
# 157  North America            NaN                               Curaçao
# 158  North America            NaN                                 Aruba
# 159  North America            NaN            Sint Maarten (Netherlands)
# 160  North America            NaN      Bonaire, Sint Eustatius and Saba
# 164  North America            NaN                Nicaragua, Republic of
# 172  North America            NaN  United States Minor Outlying Islands
# 177  North America            NaN                   Panama, Republic of
# 187  North America            NaN          Puerto Rico, Commonwealth of
# 194  North America            NaN                      Saint Barthelemy
# 196  North America            NaN  Saint Kitts and Nevis, Federation of
# 197  North America            NaN                              Anguilla
# 198  North America            NaN                           Saint Lucia
# 199  North America            NaN                          Saint Martin
# 200  North America            NaN             Saint Pierre and Miquelon
# 201  North America            NaN      Saint Vincent and the Grenadines
# 231  North America            NaN      Trinidad and Tobago, Republic of
# 237  North America            NaN              Turks and Caicos Islands
# 248  North America            NaN              United States of America
# 249  North America            NaN          United States Virgin Islands
#
#     Two_Letter_Country_Code Three_Letter_Country_Code  Country_Number  \
# 7                        AG                       ATG            28.0
# 13                       BS                       BHS            44.0
# 18                       BB                       BRB            52.0
# 20                       BM                       BMU            60.0
# 27                       BZ                       BLZ            84.0
# 30                       VG                       VGB            92.0
# 38                       CA                       CAN           124.0
# 40                       KY                       CYM           136.0
# 55                       CR                       CRI           188.0
# 57                       CU                       CUB           192.0
# 63                       DM                       DMA           212.0
# 64                       DO                       DOM           214.0
# 66                       SV                       SLV           222.0
# 92                       GL                       GRL           304.0
# 93                       GD                       GRD           308.0
# 94                       GP                       GLP           312.0
# 96                       GT                       GTM           320.0
# 99                       HT                       HTI           332.0
# 102                      HN                       HND           340.0
# 114                      JM                       JAM           388.0
# 140                      MQ                       MTQ           474.0
# 143                      MX                       MEX           484.0
# 148                      MS                       MSR           500.0
# 156                      AN                       ANT           530.0
# 157                      CW                       CUW           531.0
# 158                      AW                       ABW           533.0
# 159                      SX                       SXM           534.0
# 160                      BQ                       BES           535.0
# 164                      NI                       NIC           558.0
# 172                      UM                       UMI           581.0
# 177                      PA                       PAN           591.0
# 187                      PR                       PRI           630.0
# 194                      BL                       BLM           652.0
# 196                      KN                       KNA           659.0
# 197                      AI                       AIA           660.0
# 198                      LC                       LCA           662.0
# 199                      MF                       MAF           663.0
# 200                      PM                       SPM           666.0
# 201                      VC                       VCT           670.0
# 231                      TT                       TTO           780.0
# 237                      TC                       TCA           796.0
# 248                      US                       USA           840.0
# 249                      VI                       VIR           850.0
#
#                              country_names
# 7                     Antigua and Barbuda,
# 13           Bahamas, Commonwealth of the,
# 18                               Barbados,
# 20                                Bermuda,
# 27                                 Belize,
# 30                 British Virgin Islands,
# 38                                 Canada,
# 40                         Cayman Islands,
# 55                Costa Rica, Republic of,
# 57                      Cuba, Republic of,
# 63              Dominica, Commonwealth of,
# 64                     Dominican Republic,
# 66               El Salvador, Republic of,
# 92                              Greenland,
# 93                                Grenada,
# 94                             Guadeloupe,
# 96                 Guatemala, Republic of,
# 99                     Haiti, Republic of,
# 102                 Honduras, Republic of,
# 114                               Jamaica,
# 140                            Martinique,
# 143         Mexico, United Mexican States,
# 148                            Montserrat,
# 156                  Netherlands Antilles,
# 157                               Curaçao,
# 158                                 Aruba,
# 159            Sint Maarten (Netherlands),
# 160      Bonaire, Sint Eustatius and Saba,
# 164                Nicaragua, Republic of,
# 172  United States Minor Outlying Islands,
# 177                   Panama, Republic of,
# 187          Puerto Rico, Commonwealth of,
# 194                      Saint Barthelemy,
# 196  Saint Kitts and Nevis, Federation of,
# 197                              Anguilla,
# 198                           Saint Lucia,
# 199                          Saint Martin,
# 200             Saint Pierre and Miquelon,
# 201      Saint Vincent and the Grenadines,
# 231      Trinidad and Tobago, Republic of,
# 237              Turks and Caicos Islands,
# 248              United States of America,
# 249          United States Virgin Islands,

# %%
split = continent["country_names"].str.split(",",expand=True)
new_df = pd.merge(continent , split, left_index=True, right_index=True,how="left")
new_df
# Out:
#     Continent_Name Continent_Code  \
# 0             Asia             AS
# 1           Europe             EU
# 2       Antarctica             AN
# 3           Africa             AF
# 4          Oceania             OC
# ..             ...            ...
# 257         Africa             AF
# 258        Oceania             OC
# 259           Asia             AS
# 260           Asia             AS
# 261           Asia             AS
#
#                                      Country_Name Two_Letter_Country_Code  \
# 0                Afghanistan, Islamic Republic of                      AF
# 1                            Albania, Republic of                      AL
# 2    Antarctica (the territory South of 60 deg S)                      AQ
# 3        Algeria, People's Democratic Republic of                      DZ
# 4                                  American Samoa                      AS
# ..                                            ...                     ...
# 257                           Zambia, Republic of                      ZM
# 258                            Disputed Territory                      XX
# 259                Iraq-Saudi Arabia Neutral Zone                      XE
# 260                   United Nations Neutral Zone                      XD
# 261                               Spratly Islands                      XS
#
#     Three_Letter_Country_Code  Country_Number  \
# 0                         AFG             4.0
# 1                         ALB             8.0
# 2                         ATA            10.0
# 3                         DZA            12.0
# 4                         ASM            16.0
# ..                        ...             ...
# 257                       ZMB           894.0
# 258                       NaN             NaN
# 259                       NaN             NaN
# 260                       NaN             NaN
# 261                       NaN             NaN
#
#                                      country_names  \
# 0                Afghanistan, Islamic Republic of,
# 1                            Albania, Republic of,
# 2    Antarctica (the territory South of 60 deg S),
# 3        Algeria, People's Democratic Republic of,
# 4                                  American Samoa,
# ..                                             ...
# 257                           Zambia, Republic of,
# 258                            Disputed Territory,
# 259                Iraq-Saudi Arabia Neutral Zone,
# 260                   United Nations Neutral Zone,
# 261                               Spratly Islands,
#
#                                                 0  \
# 0                                     Afghanistan
# 1                                         Albania
# 2    Antarctica (the territory South of 60 deg S)
# 3                                         Algeria
# 4                                  American Samoa
# ..                                            ...
# 257                                        Zambia
# 258                            Disputed Territory
# 259                Iraq-Saudi Arabia Neutral Zone
# 260                   United Nations Neutral Zone
# 261                               Spratly Islands
#
#                                     1     2
# 0                 Islamic Republic of
# 1                         Republic of
# 2                                      None
# 3     People's Democratic Republic of
# 4                                      None
# ..                                ...   ...
# 257                       Republic of
# 258                                    None
# 259                                    None
# 260                                    None
# 261                                    None
#
# [262 rows x 10 columns]

# %%
new_df = new_df[["Continent_Name","Three_Letter_Country_Code", 0 ]]

# %%
new_df = new_df.rename( columns = {0 : "Country_x1"})

# %%
#new_df.to_csv("/Users/eamonnmccallum/Monash-DS/groupwork/STDs/work/data/contient_&_country_list.csv")

# %%
check = new_df.loc[new_df["Country_x1"]== "United States"]
check
# Out:
# Empty DataFrame
# Columns: [index, Continent_Name, Three_Letter_Country_Code, Country_x1]
# Index: []

# %%
new_df = new_df.astype({"Country_x1": str })
new_df = new_df.sort_values("Country_x1")
new_df = new_df.reset_index()
new_df.tail(20)
# Out:
#      index Continent_Name Three_Letter_Country_Code  \
# 242    239         Africa                       UGA
# 243    240         Europe                       UKR
# 244    232           Asia                       ARE
# 245    243         Europe                       GBR
# 246    260           Asia                       NaN
# 247    171        Oceania                       UMI
# 248    172  North America                       UMI
# 249    249  North America                       VIR
# 250    248  North America                       USA
# 251    251  South America                       URY
# 252    252           Asia                       UZB
# 253    162        Oceania                       VUT
# 254    253  South America                       VEN
# 255    211           Asia                       VNM
# 256    254        Oceania                       WLF
# 257    218         Africa                       ESH
# 258    256           Asia                       YEM
# 259    257         Africa                       ZMB
# 260    215         Africa                       ZWE
# 261     76         Europe                       ALA
#
#                                             Country_x1
# 242                                             Uganda
# 243                                            Ukraine
# 244                               United Arab Emirates
# 245  United Kingdom of Great Britain & Northern Ire...
# 246                        United Nations Neutral Zone
# 247               United States Minor Outlying Islands
# 248               United States Minor Outlying Islands
# 249                       United States Virgin Islands
# 250                           United States of America
# 251                                            Uruguay
# 252                                         Uzbekistan
# 253                                            Vanuatu
# 254                                          Venezuela
# 255                                            Vietnam
# 256                                  Wallis and Futuna
# 257                                     Western Sahara
# 258                                              Yemen
# 259                                             Zambia
# 260                                           Zimbabwe
# 261                                      Åland Islands

# %%
clean_df = pd.read_csv("/Users/eamonnmccallum/Monash-DS/groupwork/STDs/work/data/numbeo_ranking_country.csv")

# %%
clean_df = clean_df.astype({"Country": str })
clean_df = clean_df.sort_values("Country")
working_df1 = pd.DataFrame(clean_df["Country"])
working_df1 = working_df1.drop_duplicates()
working_df1
# Out:
#         Country
# 96      Albania
# 449     Algeria
# 395   Argentina
# 332     Armenia
# 356   Australia
# ..          ...
# 58   Uzbekistan
# 320   Venezuela
# 429     Vietnam
# 183      Zambia
# 37     Zimbabwe
#
# [130 rows x 1 columns]

# %%
combined_df = pd.merge(working_df1, new_df, left_on="Country", right_on="Country_x1", how='inner' )
combined_df.to_csv("working_country_contin.csv")

# %%
combined_df = combined_df[["Country", "Continent_Name", "Three_Letter_Country_Code"]]

# %%
final_df = pd.merge(clean_df, combined_df, on="Country", how='left' )

# %%
final_df.to_csv("combined_test.csv")

# %%
nan_df = final_df[final_df['Continent_Name'].isnull()]

# %%
nan_df
# Out:
#      Unnamed: 0                      Country  Year  Ranking  \
# 79           85       Bosnia And Herzegovina  2018       86
# 80           86       Bosnia And Herzegovina  2019       87
# 81          105       Bosnia And Herzegovina  2016      106
# 82           95       Bosnia And Herzegovina  2015       96
# 83           98       Bosnia And Herzegovina  2017       99
# 90           51                       Brunei  2016       52
# 298         108  Kosovo (Disputed Territory)  2018      109
# 299         114  Kosovo (Disputed Territory)  2019      115
# 300         102  Kosovo (Disputed Territory)  2015      103
# 316          70                        Libya  2015       71
# 317          72                        Libya  2017       73
# 318          84                        Libya  2016       85
# 394          92              North Macedonia  2018       93
# 395         108              North Macedonia  2017      109
# 396         111              North Macedonia  2015      112
# 397         101              North Macedonia  2019      102
# 398         110              North Macedonia  2016      111
# 410          40                    Palestine  2018       41
# 411          50                    Palestine  2019       51
# 412          65                    Palestine  2015       66
